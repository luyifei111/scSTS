# %%
import igraph
import squidpy as sq
import os
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
import scanpy as sc

# %%
sample = "T1642"

# %%
adata = sc.read_h5ad(f"/cluster3/yflu/STS/TMA/separated/{sample}/{sample}_nico_1.h5ad")

# %%
sq.gr.spatial_neighbors(adata, coord_type="generic", delaunay=True)

# %%
sq.gr.centrality_scores(adata, cluster_key="Celltype_united")

# %%
sq.pl.centrality_scores(adata, cluster_key="Celltype_united", figsize=(16, 5))

# %%
sq.gr.co_occurrence(
    adata,
    cluster_key="celltype_sp",
)

# %%
sq.pl.co_occurrence(
    adata,
    cluster_key="celltype_sp",
    clusters="Fibroblasts",
    figsize=(10, 10),
)

# %%
sq.gr.nhood_enrichment(adata, cluster_key="Celltype_united")

# %%
fig, ax = plt.subplots(1, 2, figsize=(13, 7))
sq.pl.nhood_enrichment(
    adata,
    cluster_key="celltype_sp",
    figsize=(8, 8),
    title="Neighborhood enrichment adata",
    ax=ax[0],
)
sq.pl.spatial_scatter(adata, color="celltype_sp", shape=None, size=2, ax=ax[1])

# %%
sq.gr.spatial_neighbors(adata, coord_type="generic", delaunay=True)
sq.gr.spatial_autocorr(
    adata,
    mode="moran",
    n_perms=100,
    n_jobs=1,
)
adata_subsample.uns["moranI"].head(10)
